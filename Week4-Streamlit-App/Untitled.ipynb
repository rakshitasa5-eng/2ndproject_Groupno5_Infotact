# %%
import os
print(os.getcwd())
# Out:
# C:\Users\ASUS\Downloads\Week4-Streamlit-App

# %%
print(os.listdir('.'))
# Out:
# ['.ipynb_checkpoints', '06_Streamlit_Deployment (1).ipynb', 'app (2).py', 'best_model_per_category.csv', 'final_anomaly_dataset.csv', 'future_demand_forecast.csv', 'model_comparison_results.csv', 'monthly_demand_clean.csv', 'requirements.txt', 'Untitled.ipynb']

# %%
required = ['app.py', 'requirements.txt', '06_Streamlit_Deployment.ipynb',
            'monthly_demand_clean.csv', 'final_anomaly_dataset.csv',
            'future_demand_forecast.csv', 'model_comparison_results.csv',
            'best_model_per_category.csv']
missing = [f for f in required if not os.path.exists(f)]
print("Missing:", missing if missing else "ALL FILES PRESENT — proceed")
# Out:
# Missing: ['app.py', '06_Streamlit_Deployment.ipynb']
